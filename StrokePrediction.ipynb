# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#importing python classes and packages
import matplotlib.pyplot as plt
from tkinter.filedialog import askopenfilename
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.naive_bayes import GaussianNB
import seaborn as sns
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn import svm
from sklearn.linear_model import LogisticRegression
#import shap
from imblearn.over_sampling import SMOTE
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest
import catboost as cb

# %%
#load and display dataset values
dataset = pd.read_csv("Dataset/healthcare-dataset-stroke-data.csv")
dataset.fillna(0, inplace = True)
dataset
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   0.0     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   0.0     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                5110 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
dataset['work_type'].value_counts()
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %%
dataset['Residence_type'].value_counts()
# Out:
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64

# %%
dataset['ever_married'].value_counts()
# Out:
# Yes    3353
# No     1757
# Name: ever_married, dtype: int64

# %%
dataset['smoking_status'].value_counts()
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %%
#finidng and plotting labels in dataset and in below graph we can see dataset is highly imbalance as one class contains
#so many instances and other contains very few instances and this imbalance we will handle using SMOTE
unique, count = np.unique(dataset['stroke'], return_counts = True)
labels = ['Normal', 'Stroke']
height = count
bars = labels
y_pos = np.arange(len(bars))
plt.bar(y_pos, height)
plt.xticks(y_pos, bars)
plt.xlabel("Target (0) Normal (1) Stroke")
plt.ylabel("Count")
plt.title("Target Samples Distribution from Original Dataset")
plt.show()

# %%
#graphs of different labels found in dataset
plt.pie(count, labels = labels)
plt.title("Distribution of Target Graph")
plt.show()

# %%
#find and plot features cluster correlation graph
plt.figure(figsize=(14,8))
sns.heatmap(dataset.corr(), cmap='coolwarm', annot=True)
plt.title("Features Clustering Graph")
plt.show()

# %%
#plot graph of stroke patient based on age and gender
temp = dataset.loc[dataset['stroke'] == 1]
sns.violinplot(x='gender',y='age',data=temp,palette='rainbow')
plt.title("Stroke Patient Age on Gender")
plt.show()

# %%
#plot graph of stroke patient based on age and gender in bar graph
data = temp[['age', 'gender']]
data.groupby(['age', 'gender']).size().unstack().plot(kind='bar', stacked=True, figsize=(14,6))
plt.xlabel("Age")
plt.ylabel(count)
plt.title("Age Distribution of Stroke Patients")
# Out:
# Text(0.5, 1.0, 'Age Distribution of Stroke Patients')

# %%
#graph of Stroke Patient using BMI on Gender
sns.violinplot(x='gender',y='bmi',data=temp,palette='rainbow')
plt.title("Stroke Patient BMI on Gender")
plt.xlabel("Gender")
plt.ylabel("BMI")
plt.show()

# %%
#finding and plotting graph in stroke patient suffering from hyper tension
data = temp[['hypertension']]
data.groupby(['hypertension']).size().plot(kind='barh', color=['g', 'r'])
plt.xlabel("Total")
plt.ylabel("Hypertension 1 (yes) & 0 (No)")
plt.title("Stroke Patient's Hypertension Status")
# Out:
# Text(0.5, 1.0, "Stroke Patient's Hypertension Status")

# %%
#finding and plotting graph in stroke patient suffering from heart disease
data = temp[['heart_disease']]
data.groupby(['heart_disease']).size().plot(kind='barh', color=['g', 'r'])
plt.xlabel("Total")
plt.ylabel("Heart Disease  1 (yes) & 0 (No)")
plt.title("Stroke Patient's Heart Disease")
# Out:
# Text(0.5, 1.0, "Stroke Patient's Heart Disease")

# %%
#finding and plotting graph in stroke patient with average glucose level
sns.violinplot(x='gender',y='avg_glucose_level',data=temp,palette='rainbow')
plt.title("Stroke Patient's Average Glucose Level on Gender.")
plt.xlabel("Gender")
plt.ylabel("Average Glucose Level")
plt.show()

# %%
#finding and plotting graph in stroke patient doing smoking
data = temp[['smoking_status']]
data.groupby(['smoking_status']).size().plot(kind='barh', color=['b', 'r', 'g', 'y'])
plt.xlabel("Total")
plt.ylabel("Smoking Status")
plt.title("Stroke Patient's Smoking Status")
# Out:
# Text(0.5, 1.0, "Stroke Patient's Smoking Status")

# %%
#finding and plotting graph of stroke patient using residence type
unique, count = np.unique(temp['Residence_type'], return_counts=True)
plt.pie(count, labels = unique, autopct='%1.2f%%')
plt.title("Stroke Patients Residence Type Graph")
plt.show()

# %%
# Import label encoder 
from sklearn import preprocessing 

# label_encoder object knows 
# how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 

dataset['gender'] = label_encoder.fit_transform(dataset['gender']) #encode all str columns to numeric 
dataset['ever_married'] = label_encoder.fit_transform(dataset['ever_married']) #encode all str columns to numeric
dataset['work_type'] = label_encoder.fit_transform(dataset['work_type']) #
dataset['Residence_type'] = label_encoder.fit_transform(dataset['Residence_type']) #
dataset['smoking_status'] = label_encoder.fit_transform(dataset['smoking_status']) #
dataset
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 0      9046       1  67.0             0              1             1
# 1     51676       0  61.0             0              0             1
# 2     31112       1  80.0             0              1             1
# 3     60182       0  49.0             0              0             1
# 4      1665       0  79.0             1              0             1
# ...     ...     ...   ...           ...            ...           ...
# 5105  18234       0  80.0             1              0             1
# 5106  44873       0  81.0             0              0             1
# 5107  19723       0  35.0             0              0             1
# 5108  37544       1  51.0             0              0             1
# 5109  44679       0  44.0             0              0             1
#
#       work_type  Residence_type  avg_glucose_level   bmi  smoking_status  \
# 0             2               1             228.69  36.6               1
# 1             3               0             202.21   0.0               2
# 2             2               0             105.92  32.5               2
# 3             2               1             171.23  34.4               3
# 4             3               0             174.12  24.0               2
# ...         ...             ...                ...   ...             ...
# 5105          2               1              83.75   0.0               2
# 5106          3               1             125.20  40.0               2
# 5107          3               0              82.99  30.6               2
# 5108          2               0             166.29  25.6               1
# 5109          0               1              85.28  26.2               0
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
dataset.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
#drop ID column and then extract X training features and Y target label
Y = dataset['stroke'].ravel()
dataset.drop(['id', 'stroke'], axis = 1,inplace=True)
X = dataset.values
#normalized dataset features
sc1 = MinMaxScaler(feature_range = (0, 1))
X = sc1.fit_transform(X)#features normalization
print("Normalize Features : "+str(X))
# Out:
# Normalize Features : [[0.5        0.81689453 0.         ... 0.80126489 0.375      0.33333333]
#  [0.         0.74365234 0.         ... 0.67902317 0.         0.66666667]
#  [0.5        0.97558594 0.         ... 0.23451205 0.3329918  0.66666667]
#  ...
#  [0.         0.42626953 0.         ... 0.12865848 0.31352459 0.66666667]
#  [0.5        0.62158203 0.         ... 0.51320284 0.26229508 0.33333333]
#  [0.         0.53613281 0.         ... 0.13922999 0.26844262 0.        ]]

# %%
#now apply Smote to balance dataset
sm = SMOTE()
X, Y = sm.fit_resample(X, Y)
unique, count = np.unique(Y, return_counts=True)
height = count
bars = labels
y_pos = np.arange(len(bars))
plt.bar(y_pos, height)
plt.xticks(y_pos, bars)
plt.xlabel("Target (0) Normal (1) Stroke")
plt.ylabel("Count")
plt.title("Target Samples Distribution after applying SMOTE")
plt.show()

# %%
#now select features uisng CHI Square features selection algorithm
print("Features available in dataset before selection : "+str(X.shape[1]))
features_selector = SelectKBest(score_func=chi2, k = 9)
selected_features = features_selector.fit_transform(X, Y)
print("Features available in dataset after selection : "+str(selected_features.shape[1]))
# Out:
# Features available in dataset before selection : 10
# Features available in dataset after selection : 9

# %%
features_selector.get_support()
# Out:
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
#split dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(selected_features, Y, test_size=0.2) #split dataset into train and test
print()
print("Dataset train & test split as 80% dataset for training and 20% for testing")
print("Training Size (80%): "+str(X_train.shape[0])) #print training and test size
print("Testing Size (20%): "+str(X_test.shape[0]))
print()
# Out:
# Dataset train & test split as 80% dataset for training and 20% for testing
# Training Size (80%): 7777
# Testing Size (20%): 1945

# %%
#define global variables to calculate and store accuracy and other metrics
precision = []
recall = []
fscore = []
accuracy = []

# %%
ML_Model = []
acc = []
prec = []
rec = []
f1 = []

#function to call for storing the results
def storeResults(model, a,b,c,d):
    ML_Model.append(model)
    acc.append(round(a, 3))
    prec.append(round(b, 3))
    rec.append(round(c, 3))
    f1.append(round(d, 3))

# %%
#function to calculate various metrics such as accuracy, precision etc
def calculateMetrics(algorithm, predict, testY):
    p = precision_score(testY, predict,average='macro') * 100
    r = recall_score(testY, predict,average='macro') * 100
    f = f1_score(testY, predict,average='macro') * 100
    a = accuracy_score(testY,predict)*100     
    print()
    print(algorithm+' Accuracy  : '+str(a))
    print(algorithm+' Precision   : '+str(p))
    print(algorithm+' Recall      : '+str(r))
    print(algorithm+' FMeasure    : '+str(f))    
    accuracy.append(a)
    precision.append(p)
    recall.append(r)
    fscore.append(f)
    labels = unique
    conf_matrix = confusion_matrix(testY, predict) 
    plt.figure(figsize =(5, 5)) 
    ax = sns.heatmap(conf_matrix, xticklabels = labels, yticklabels = labels, annot = True, cmap="viridis" ,fmt ="g");
    ax.set_ylim([0,len(labels)])
    plt.title(algorithm+" Confusion matrix") 
    plt.ylabel('True class') 
    plt.xlabel('Predicted class') 
    plt.show()

# %% [markdown]
# # Random Forest

# %%
#train random forest algorithm on training dataset and test its prediction capability on test data
#now train Random Forest algorithm
rf_cls = RandomForestClassifier()
rf_cls.fit(X_train, y_train)
predict = rf_cls.predict(X_test)
calculateMetrics("Random Forest", predict, y_test)
# Out:
# Random Forest Accuracy  : 95.21850899742931
# Random Forest Precision   : 95.24352983274859
# Random Forest Recall      : 95.20122692897561
# Random Forest FMeasure    : 95.2150888773731

# %%
rf_acc = accuracy_score(predict, y_test)
rf_prec = precision_score(predict, y_test,average='macro')
rf_rec = recall_score(predict, y_test,average='macro')
rf_f1 = f1_score(predict, y_test,average='macro')

# %%
storeResults('Random Forest',rf_acc,rf_prec,rf_rec,rf_f1)

# %% [markdown]
# # Logistic Regression

# %%
#now train LogisticRegression algorithm
lr_cls = LogisticRegression()#define regression object
lr_cls.fit(X_train, y_train)#train regression on training data
predict = lr_cls.predict(X_test)#perform prediction on test data
calculateMetrics("Logistic Regression", predict, y_test)#calculate accuracy and other metrics
# Out:
# Logistic Regression Accuracy  : 77.73778920308483
# Logistic Regression Precision   : 77.78936541498955
# Logistic Regression Recall      : 77.69078216722195
# Logistic Regression FMeasure    : 77.70192862424909

# %%
lr_acc = accuracy_score(predict, y_test)
lr_prec = precision_score(predict, y_test,average='macro')
lr_rec = recall_score(predict, y_test,average='macro')
lr_f1 = f1_score(predict, y_test,average='macro')

# %%
storeResults('Logistic Regression',lr_acc,lr_prec,lr_rec,lr_f1)

# %% [markdown]
# # SVM

# %%
#now train SVM algorithm
svm_cls = svm.SVC()#define SVM object
svm_cls.fit(X_train, y_train)#train SVM on training data
predict = svm_cls.predict(X_test)#perform prediction on test data
calculateMetrics("SVM", predict, y_test)#calculate accuracy and other metrics
# Out:
# SVM Accuracy  : 80.92544987146529
# SVM Precision   : 81.21359680679754
# SVM Recall      : 80.8350520915966
# SVM FMeasure    : 80.84506346842134

# %%
svm_acc = accuracy_score(predict, y_test)
svm_prec = precision_score(predict, y_test,average='macro')
svm_rec = recall_score(predict, y_test,average='macro')
svm_f1 = f1_score(predict, y_test,average='macro')

# %%
storeResults('SVM',svm_acc,svm_prec,svm_rec,svm_f1)

# %% [markdown]
# # KNN

# %%
#now train KNN algorithm
knn_cls =  KNeighborsClassifier(n_neighbors=3)#define KNN object
knn_cls.fit(X_train, y_train)#train KNN on training data
predict = knn_cls.predict(X_test)#perform prediction on test data
calculateMetrics("KNN", predict, y_test)#calculate accuracy and other metrics
# Out:
# KNN Accuracy  : 92.69922879177378
# KNN Precision   : 93.24158647136372
# KNN Recall      : 92.60246443492517
# KNN FMeasure    : 92.66282633274676

# %%
knn_acc = accuracy_score(predict, y_test)
knn_prec = precision_score(predict, y_test,average='macro')
knn_rec = recall_score(predict, y_test,average='macro')
knn_f1 = f1_score(predict, y_test,average='macro')

# %%
storeResults('KNN',knn_acc,knn_prec,knn_rec,knn_f1)

# %% [markdown]
# # Naive Bayes

# %%
#now train Naive Bayes algorithm
nb_cls =  GaussianNB()#define Naive Bayes object
nb_cls.fit(X_train, y_train)#train Naive Bayes on training data
predict = nb_cls.predict(X_test)#perform prediction on test data
calculateMetrics("Naive Bayes", predict, y_test)#calculate accuracy and other metrics
# Out:
# Naive Bayes Accuracy  : 75.16709511568124
# Naive Bayes Precision   : 75.1758567720748
# Naive Bayes Recall      : 75.1359141149717
# Naive Bayes FMeasure    : 75.14344113191821

# %%
nb_acc = accuracy_score(predict, y_test)
nb_prec = precision_score(predict, y_test,average='macro')
nb_rec = recall_score(predict, y_test,average='macro')
nb_f1 = f1_score(predict, y_test,average='macro')

# %%
storeResults('Naive BAyes',nb_acc,nb_prec,nb_rec,nb_f1)

# %% [markdown]
# # XGBoost

# %%
#now train XGBoost algorithm
xg_cls =  XGBClassifier(n_estimators=10)#define XGBOOST object
xg_cls.fit(X_train, y_train)#train XGBOost on training data
predict = xg_cls.predict(X_test)#perform prediction on test data
calculateMetrics("XGBoost", predict, y_test)#calculate accuracy and other metrics
# Out:
# XGBoost Accuracy  : 89.51156812339332
# XGBoost Precision   : 89.6701667669835
# XGBoost Recall      : 89.45634354011317
# XGBoost FMeasure    : 89.48855869431145

# %%
xgb_acc = accuracy_score(predict, y_test)
xgb_prec = precision_score(predict, y_test,average='macro')
xgb_rec = recall_score(predict, y_test,average='macro')
xgb_f1 = f1_score(predict, y_test,average='macro')

# %%
storeResults('XGBoost',xgb_acc,xgb_prec,xgb_rec,xgb_f1)

# %% [markdown]
# # CatBoost

# %%
#now traon extension CATBOOST algorithm as extension which is more advanced then other ML algorithm
cb_cls = cb.CatBoostClassifier(iterations=300, learning_rate=0.1)
cb_cls.fit(X_train, y_train)#train CatBoost on training data
predict = cb_cls.predict(X_test)#perform prediction on test data
calculateMetrics("Extension CatBoost", predict, y_test)#calculate accuracy and other metrics
# Out:
# 0:	learn: 0.6398832	total: 2.67ms	remaining: 798ms
# 1:	learn: 0.5918493	total: 4.94ms	remaining: 736ms
# 2:	learn: 0.5344397	total: 7.6ms	remaining: 753ms
# 3:	learn: 0.5118012	total: 9.85ms	remaining: 729ms
# 4:	learn: 0.4796878	total: 12.1ms	remaining: 716ms
# 5:	learn: 0.4574463	total: 14.5ms	remaining: 709ms
# 6:	learn: 0.4330238	total: 16.9ms	remaining: 708ms
# 7:	learn: 0.4167001	total: 19.2ms	remaining: 700ms
# 8:	learn: 0.4037363	total: 21.5ms	remaining: 697ms
# 9:	learn: 0.3925634	total: 24.5ms	remaining: 709ms
# 10:	learn: 0.3768848	total: 26.9ms	remaining: 707ms
# 11:	learn: 0.3604020	total: 29.5ms	remaining: 708ms
# 12:	learn: 0.3525379	total: 32ms	remaining: 707ms
# 13:	learn: 0.3465255	total: 34.6ms	remaining: 708ms
# 14:	learn: 0.3429994	total: 37ms	remaining: 703ms
# 15:	learn: 0.3382846	total: 39.3ms	remaining: 697ms
# 16:	learn: 0.3338897	total: 41.6ms	remaining: 692ms
# 17:	learn: 0.3313456	total: 44ms	remaining: 689ms
# 18:	learn: 0.3248467	total: 46.8ms	remaining: 692ms
# 19:	learn: 0.3197722	total: 49.7ms	remaining: 696ms
# 20:	learn: 0.3139744	total: 52.5ms	remaining: 697ms
# 21:	learn: 0.3113183	total: 55.3ms	remaining: 698ms
# 22:	learn: 0.3089374	total: 58.2ms	remaining: 701ms
# 23:	learn: 0.3071213	total: 61.2ms	remaining: 704ms
# 24:	learn: 0.3047722	total: 63.6ms	remaining: 700ms
# 25:	learn: 0.2991737	total: 66.7ms	remaining: 703ms
# 26:	learn: 0.2938099	total: 69.4ms	remaining: 702ms
# 27:	learn: 0.2911459	total: 71.9ms	remaining: 698ms
# 28:	learn: 0.2877874	total: 74.2ms	remaining: 694ms
# 29:	learn: 0.2821182	total: 76.6ms	remaining: 690ms
# 30:	learn: 0.2805848	total: 79ms	remaining: 686ms
# 31:	learn: 0.2784705	total: 81.5ms	remaining: 682ms
# 32:	learn: 0.2761175	total: 83.9ms	remaining: 679ms
# 33:	learn: 0.2724786	total: 86.3ms	remaining: 675ms
# 34:	learn: 0.2700660	total: 89.3ms	remaining: 676ms
# 35:	learn: 0.2685014	total: 91.7ms	remaining: 673ms
# 36:	learn: 0.2667106	total: 94.5ms	remaining: 672ms
# 37:	learn: 0.2649727	total: 97.1ms	remaining: 669ms
# 38:	learn: 0.2615970	total: 99.8ms	remaining: 668ms
# 39:	learn: 0.2598158	total: 102ms	remaining: 666ms
# 40:	learn: 0.2576299	total: 105ms	remaining: 662ms
# 41:	learn: 0.2549830	total: 108ms	remaining: 661ms
# 42:	learn: 0.2533548	total: 110ms	remaining: 658ms
# 43:	learn: 0.2502280	total: 113ms	remaining: 656ms
# 44:	learn: 0.2490264	total: 115ms	remaining: 652ms
# 45:	learn: 0.2469315	total: 118ms	remaining: 651ms
# 46:	learn: 0.2456149	total: 120ms	remaining: 648ms
# 47:	learn: 0.2447284	total: 123ms	remaining: 647ms
# 48:	learn: 0.2429735	total: 126ms	remaining: 644ms
# 49:	learn: 0.2409281	total: 128ms	remaining: 640ms
# 50:	learn: 0.2395966	total: 131ms	remaining: 639ms
# 51:	learn: 0.2383359	total: 134ms	remaining: 638ms
# 52:	learn: 0.2357116	total: 136ms	remaining: 636ms
# 53:	learn: 0.2345285	total: 139ms	remaining: 632ms
# 54:	learn: 0.2337145	total: 141ms	remaining: 629ms
# 55:	learn: 0.2325319	total: 143ms	remaining: 625ms
# 56:	learn: 0.2310743	total: 146ms	remaining: 622ms
# 57:	learn: 0.2302089	total: 148ms	remaining: 618ms
# 58:	learn: 0.2292123	total: 150ms	remaining: 615ms
# 59:	learn: 0.2275496	total: 153ms	remaining: 612ms
# 60:	learn: 0.2263870	total: 156ms	remaining: 610ms
# 61:	learn: 0.2242598	total: 158ms	remaining: 607ms
# 62:	learn: 0.2227014	total: 160ms	remaining: 603ms
# 63:	learn: 0.2205438	total: 163ms	remaining: 600ms
# 64:	learn: 0.2193417	total: 166ms	remaining: 599ms
# 65:	learn: 0.2184174	total: 168ms	remaining: 595ms
# 66:	learn: 0.2179068	total: 170ms	remaining: 592ms
# 67:	learn: 0.2162929	total: 173ms	remaining: 589ms
# 68:	learn: 0.2148198	total: 175ms	remaining: 587ms
# 69:	learn: 0.2138302	total: 178ms	remaining: 584ms
# 70:	learn: 0.2130765	total: 180ms	remaining: 581ms
# 71:	learn: 0.2120955	total: 183ms	remaining: 578ms
# 72:	learn: 0.2102340	total: 185ms	remaining: 575ms
# 73:	learn: 0.2090298	total: 188ms	remaining: 575ms
# 74:	learn: 0.2081985	total: 191ms	remaining: 572ms
# 75:	learn: 0.2074791	total: 193ms	remaining: 569ms
# 76:	learn: 0.2064726	total: 195ms	remaining: 566ms
# 77:	learn: 0.2050062	total: 198ms	remaining: 563ms
# 78:	learn: 0.2037112	total: 201ms	remaining: 561ms
# 79:	learn: 0.2022966	total: 203ms	remaining: 559ms
# 80:	learn: 0.2016240	total: 206ms	remaining: 556ms
# 81:	learn: 0.2009430	total: 208ms	remaining: 553ms
# 82:	learn: 0.2003365	total: 211ms	remaining: 552ms
# 83:	learn: 0.1997661	total: 213ms	remaining: 549ms
# 84:	learn: 0.1988087	total: 216ms	remaining: 548ms
# 85:	learn: 0.1983226	total: 219ms	remaining: 546ms
# 86:	learn: 0.1970282	total: 222ms	remaining: 543ms
# 87:	learn: 0.1960000	total: 224ms	remaining: 540ms
# 88:	learn: 0.1949374	total: 227ms	remaining: 538ms
# 89:	learn: 0.1943393	total: 230ms	remaining: 536ms
# 90:	learn: 0.1935974	total: 232ms	remaining: 534ms
# 91:	learn: 0.1925183	total: 235ms	remaining: 531ms
# 92:	learn: 0.1909698	total: 238ms	remaining: 529ms
# 93:	learn: 0.1899897	total: 240ms	remaining: 527ms
# 94:	learn: 0.1894711	total: 243ms	remaining: 524ms
# 95:	learn: 0.1881161	total: 246ms	remaining: 522ms
# 96:	learn: 0.1871259	total: 248ms	remaining: 519ms
# 97:	learn: 0.1864594	total: 251ms	remaining: 517ms
# 98:	learn: 0.1855733	total: 253ms	remaining: 514ms
# 99:	learn: 0.1843894	total: 256ms	remaining: 511ms
# 100:	learn: 0.1830050	total: 258ms	remaining: 509ms
# 101:	learn: 0.1822331	total: 261ms	remaining: 506ms
# 102:	learn: 0.1813632	total: 264ms	remaining: 504ms
# 103:	learn: 0.1807593	total: 266ms	remaining: 502ms
# 104:	learn: 0.1786789	total: 269ms	remaining: 499ms
# 105:	learn: 0.1779508	total: 271ms	remaining: 496ms
# 106:	learn: 0.1772098	total: 274ms	remaining: 494ms
# 107:	learn: 0.1762366	total: 276ms	remaining: 491ms
# 108:	learn: 0.1752964	total: 279ms	remaining: 489ms
# 109:	learn: 0.1746321	total: 282ms	remaining: 487ms
# 110:	learn: 0.1739198	total: 284ms	remaining: 484ms
# 111:	learn: 0.1730391	total: 287ms	remaining: 482ms
# 112:	learn: 0.1715632	total: 290ms	remaining: 480ms
# 113:	learn: 0.1711621	total: 293ms	remaining: 478ms
# 114:	learn: 0.1706883	total: 295ms	remaining: 475ms
# 115:	learn: 0.1697059	total: 298ms	remaining: 472ms
# 116:	learn: 0.1693828	total: 300ms	remaining: 470ms
# 117:	learn: 0.1687096	total: 303ms	remaining: 468ms
# 118:	learn: 0.1680858	total: 305ms	remaining: 465ms
# 119:	learn: 0.1666359	total: 308ms	remaining: 462ms
# 120:	learn: 0.1657201	total: 311ms	remaining: 460ms
# 121:	learn: 0.1651931	total: 314ms	remaining: 458ms
# 122:	learn: 0.1637999	total: 316ms	remaining: 455ms
# 123:	learn: 0.1626802	total: 320ms	remaining: 454ms
# 124:	learn: 0.1613488	total: 322ms	remaining: 451ms
# 125:	learn: 0.1603962	total: 325ms	remaining: 449ms
# 126:	learn: 0.1590802	total: 328ms	remaining: 446ms
# 127:	learn: 0.1580661	total: 330ms	remaining: 443ms
# 128:	learn: 0.1572934	total: 333ms	remaining: 441ms
# 129:	learn: 0.1564525	total: 335ms	remaining: 438ms
# 130:	learn: 0.1556978	total: 338ms	remaining: 436ms
# 131:	learn: 0.1548665	total: 341ms	remaining: 434ms
# 132:	learn: 0.1540722	total: 343ms	remaining: 431ms
# 133:	learn: 0.1537007	total: 346ms	remaining: 429ms
# 134:	learn: 0.1534787	total: 349ms	remaining: 426ms
# 135:	learn: 0.1523944	total: 351ms	remaining: 423ms
# 136:	learn: 0.1511499	total: 353ms	remaining: 420ms
# 137:	learn: 0.1506679	total: 356ms	remaining: 418ms
# 138:	learn: 0.1502869	total: 359ms	remaining: 415ms
# 139:	learn: 0.1497447	total: 362ms	remaining: 413ms
# 140:	learn: 0.1490755	total: 365ms	remaining: 411ms
# 141:	learn: 0.1483911	total: 367ms	remaining: 409ms
# 142:	learn: 0.1471940	total: 370ms	remaining: 407ms
# 143:	learn: 0.1454769	total: 373ms	remaining: 404ms
# 144:	learn: 0.1448767	total: 376ms	remaining: 402ms
# 145:	learn: 0.1434393	total: 379ms	remaining: 400ms
# 146:	learn: 0.1420139	total: 381ms	remaining: 397ms
# 147:	learn: 0.1414472	total: 384ms	remaining: 394ms
# 148:	learn: 0.1409758	total: 386ms	remaining: 391ms
# 149:	learn: 0.1398969	total: 388ms	remaining: 388ms
# 150:	learn: 0.1384844	total: 391ms	remaining: 386ms
# 151:	learn: 0.1376846	total: 393ms	remaining: 383ms
# 152:	learn: 0.1370821	total: 396ms	remaining: 380ms
# 153:	learn: 0.1366862	total: 399ms	remaining: 378ms
# 154:	learn: 0.1359313	total: 401ms	remaining: 375ms
# 155:	learn: 0.1355813	total: 403ms	remaining: 372ms
# 156:	learn: 0.1341300	total: 406ms	remaining: 370ms
# 157:	learn: 0.1338719	total: 408ms	remaining: 367ms
# 158:	learn: 0.1330692	total: 411ms	remaining: 364ms
# 159:	learn: 0.1325596	total: 413ms	remaining: 362ms
# 160:	learn: 0.1323323	total: 416ms	remaining: 359ms
# 161:	learn: 0.1317825	total: 418ms	remaining: 356ms
# 162:	learn: 0.1314775	total: 421ms	remaining: 354ms
# 163:	learn: 0.1307230	total: 423ms	remaining: 351ms
# 164:	learn: 0.1301927	total: 426ms	remaining: 349ms
# 165:	learn: 0.1291217	total: 429ms	remaining: 346ms
# 166:	learn: 0.1283262	total: 431ms	remaining: 343ms
# 167:	learn: 0.1278606	total: 433ms	remaining: 340ms
# 168:	learn: 0.1276949	total: 436ms	remaining: 338ms
# 169:	learn: 0.1270510	total: 439ms	remaining: 335ms
# 170:	learn: 0.1266988	total: 441ms	remaining: 333ms
# 171:	learn: 0.1261350	total: 444ms	remaining: 330ms
# 172:	learn: 0.1255541	total: 447ms	remaining: 328ms
# 173:	learn: 0.1253433	total: 449ms	remaining: 325ms
# 174:	learn: 0.1248663	total: 452ms	remaining: 323ms
# 175:	learn: 0.1239097	total: 455ms	remaining: 320ms
# 176:	learn: 0.1232318	total: 458ms	remaining: 318ms
# 177:	learn: 0.1228661	total: 460ms	remaining: 315ms
# 178:	learn: 0.1219320	total: 462ms	remaining: 313ms
# 179:	learn: 0.1216382	total: 465ms	remaining: 310ms
# 180:	learn: 0.1212184	total: 468ms	remaining: 307ms
# 181:	learn: 0.1210256	total: 470ms	remaining: 305ms
# 182:	learn: 0.1204341	total: 472ms	remaining: 302ms
# 183:	learn: 0.1198374	total: 475ms	remaining: 299ms
# 184:	learn: 0.1194949	total: 477ms	remaining: 297ms
# 185:	learn: 0.1189854	total: 480ms	remaining: 294ms
# 186:	learn: 0.1183700	total: 482ms	remaining: 292ms
# 187:	learn: 0.1177982	total: 485ms	remaining: 289ms
# 188:	learn: 0.1173794	total: 488ms	remaining: 286ms
# 189:	learn: 0.1166938	total: 490ms	remaining: 284ms
# 190:	learn: 0.1161296	total: 493ms	remaining: 281ms
# 191:	learn: 0.1158886	total: 495ms	remaining: 279ms
# 192:	learn: 0.1154738	total: 498ms	remaining: 276ms
# 193:	learn: 0.1147823	total: 501ms	remaining: 274ms
# 194:	learn: 0.1146304	total: 503ms	remaining: 271ms
# 195:	learn: 0.1142251	total: 506ms	remaining: 268ms
# 196:	learn: 0.1137016	total: 508ms	remaining: 266ms
# 197:	learn: 0.1129870	total: 511ms	remaining: 263ms
# 198:	learn: 0.1127510	total: 513ms	remaining: 261ms
# 199:	learn: 0.1125482	total: 516ms	remaining: 258ms
# 200:	learn: 0.1120352	total: 518ms	remaining: 255ms
# 201:	learn: 0.1118053	total: 521ms	remaining: 253ms
# 202:	learn: 0.1114731	total: 523ms	remaining: 250ms
# 203:	learn: 0.1112002	total: 527ms	remaining: 248ms
# 204:	learn: 0.1107806	total: 529ms	remaining: 245ms
# 205:	learn: 0.1100667	total: 532ms	remaining: 243ms
# 206:	learn: 0.1094915	total: 535ms	remaining: 240ms
# 207:	learn: 0.1093255	total: 538ms	remaining: 238ms
# 208:	learn: 0.1088811	total: 541ms	remaining: 235ms
# 209:	learn: 0.1085260	total: 543ms	remaining: 233ms
# 210:	learn: 0.1081583	total: 546ms	remaining: 230ms
# 211:	learn: 0.1077080	total: 548ms	remaining: 228ms
# 212:	learn: 0.1072789	total: 551ms	remaining: 225ms
# 213:	learn: 0.1071307	total: 554ms	remaining: 223ms
# 214:	learn: 0.1068895	total: 557ms	remaining: 220ms
# 215:	learn: 0.1067239	total: 559ms	remaining: 217ms
# 216:	learn: 0.1064509	total: 562ms	remaining: 215ms
# 217:	learn: 0.1060668	total: 565ms	remaining: 212ms
# 218:	learn: 0.1048855	total: 567ms	remaining: 210ms
# 219:	learn: 0.1045308	total: 570ms	remaining: 207ms
# 220:	learn: 0.1041625	total: 572ms	remaining: 204ms
# 221:	learn: 0.1030796	total: 575ms	remaining: 202ms
# 222:	learn: 0.1027691	total: 578ms	remaining: 199ms
# 223:	learn: 0.1021375	total: 580ms	remaining: 197ms
# 224:	learn: 0.1017121	total: 583ms	remaining: 194ms
# 225:	learn: 0.1012079	total: 585ms	remaining: 192ms
# 226:	learn: 0.1007441	total: 587ms	remaining: 189ms
# 227:	learn: 0.1004895	total: 590ms	remaining: 186ms
# 228:	learn: 0.1001191	total: 593ms	remaining: 184ms
# 229:	learn: 0.0999963	total: 595ms	remaining: 181ms
# 230:	learn: 0.0997189	total: 598ms	remaining: 179ms
# 231:	learn: 0.0993207	total: 601ms	remaining: 176ms
# 232:	learn: 0.0990993	total: 603ms	remaining: 173ms
# 233:	learn: 0.0988533	total: 606ms	remaining: 171ms
# 234:	learn: 0.0984331	total: 609ms	remaining: 168ms
# 235:	learn: 0.0978889	total: 612ms	remaining: 166ms
# 236:	learn: 0.0976803	total: 614ms	remaining: 163ms
# 237:	learn: 0.0974306	total: 616ms	remaining: 161ms
# 238:	learn: 0.0971763	total: 619ms	remaining: 158ms
# 239:	learn: 0.0968549	total: 621ms	remaining: 155ms
# 240:	learn: 0.0966722	total: 623ms	remaining: 153ms
# 241:	learn: 0.0963856	total: 626ms	remaining: 150ms
# 242:	learn: 0.0962029	total: 629ms	remaining: 148ms
# 243:	learn: 0.0960024	total: 631ms	remaining: 145ms
# 244:	learn: 0.0956254	total: 634ms	remaining: 142ms
# 245:	learn: 0.0951665	total: 637ms	remaining: 140ms
# 246:	learn: 0.0947682	total: 639ms	remaining: 137ms
# 247:	learn: 0.0941397	total: 642ms	remaining: 135ms
# 248:	learn: 0.0939304	total: 644ms	remaining: 132ms
# 249:	learn: 0.0937478	total: 647ms	remaining: 129ms
# 250:	learn: 0.0935179	total: 649ms	remaining: 127ms
# 251:	learn: 0.0929649	total: 652ms	remaining: 124ms
# 252:	learn: 0.0927276	total: 654ms	remaining: 122ms
# 253:	learn: 0.0926285	total: 657ms	remaining: 119ms
# 254:	learn: 0.0924650	total: 660ms	remaining: 116ms
# 255:	learn: 0.0920882	total: 662ms	remaining: 114ms
# 256:	learn: 0.0918606	total: 665ms	remaining: 111ms
# 257:	learn: 0.0916408	total: 668ms	remaining: 109ms
# 258:	learn: 0.0910481	total: 671ms	remaining: 106ms
# 259:	learn: 0.0908092	total: 673ms	remaining: 104ms
# 260:	learn: 0.0906106	total: 676ms	remaining: 101ms
# 261:	learn: 0.0899444	total: 679ms	remaining: 98.5ms
# 262:	learn: 0.0897435	total: 682ms	remaining: 95.9ms
# 263:	learn: 0.0894221	total: 684ms	remaining: 93.3ms
# 264:	learn: 0.0892357	total: 687ms	remaining: 90.7ms
# 265:	learn: 0.0889995	total: 690ms	remaining: 88.2ms
# 266:	learn: 0.0888378	total: 692ms	remaining: 85.5ms
# 267:	learn: 0.0886569	total: 694ms	remaining: 82.9ms
# 268:	learn: 0.0885425	total: 697ms	remaining: 80.3ms
# 269:	learn: 0.0881824	total: 700ms	remaining: 77.8ms
# 270:	learn: 0.0880148	total: 702ms	remaining: 75.2ms
# 271:	learn: 0.0877620	total: 705ms	remaining: 72.6ms
# 272:	learn: 0.0874487	total: 708ms	remaining: 70ms
# 273:	learn: 0.0871177	total: 710ms	remaining: 67.4ms
# 274:	learn: 0.0869335	total: 712ms	remaining: 64.8ms
# 275:	learn: 0.0866693	total: 715ms	remaining: 62.2ms
# 276:	learn: 0.0865174	total: 717ms	remaining: 59.6ms
# 277:	learn: 0.0863868	total: 720ms	remaining: 57ms
# 278:	learn: 0.0861598	total: 723ms	remaining: 54.4ms
# 279:	learn: 0.0858746	total: 726ms	remaining: 51.8ms
# 280:	learn: 0.0857233	total: 728ms	remaining: 49.2ms
# 281:	learn: 0.0855783	total: 731ms	remaining: 46.6ms
# 282:	learn: 0.0849887	total: 733ms	remaining: 44ms
# 283:	learn: 0.0847167	total: 736ms	remaining: 41.4ms
# 284:	learn: 0.0843290	total: 738ms	remaining: 38.9ms
# 285:	learn: 0.0840756	total: 741ms	remaining: 36.3ms
# 286:	learn: 0.0838606	total: 743ms	remaining: 33.7ms
# 287:	learn: 0.0837069	total: 746ms	remaining: 31.1ms
# 288:	learn: 0.0834846	total: 749ms	remaining: 28.5ms
# 289:	learn: 0.0831346	total: 751ms	remaining: 25.9ms
# 290:	learn: 0.0827127	total: 754ms	remaining: 23.3ms
# 291:	learn: 0.0826094	total: 756ms	remaining: 20.7ms
# 292:	learn: 0.0823756	total: 759ms	remaining: 18.1ms
# 293:	learn: 0.0822164	total: 761ms	remaining: 15.5ms
# 294:	learn: 0.0819582	total: 763ms	remaining: 12.9ms
# 295:	learn: 0.0816148	total: 766ms	remaining: 10.4ms
# 296:	learn: 0.0814773	total: 769ms	remaining: 7.77ms
# 297:	learn: 0.0812685	total: 771ms	remaining: 5.18ms
# 298:	learn: 0.0811243	total: 774ms	remaining: 2.59ms
# 299:	learn: 0.0809047	total: 776ms	remaining: 0us
#
# Extension CatBoost Accuracy  : 96.04113110539846
# Extension CatBoost Precision   : 96.03717216582064
# Extension CatBoost Recall      : 96.04447617536623
# Extension CatBoost FMeasure    : 96.04018904716264

# %%
cat_acc = accuracy_score(predict, y_test)
cat_prec = precision_score(predict, y_test,average='macro')
cat_rec = recall_score(predict, y_test,average='macro')
cat_f1 = f1_score(predict, y_test,average='macro')

# %%
storeResults('CatBoost',cat_acc,cat_prec,cat_rec,cat_f1)

# %% [markdown]
# # Stacking Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import StackingClassifier

estimators = [('rf', RandomForestClassifier(n_estimators=10)),('dt', DecisionTreeClassifier())]

clf = StackingClassifier(estimators=estimators, final_estimator=LGBMClassifier())

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

stac_acc_a = accuracy_score(y_test,y_pred)
stac_prec_a = precision_score(y_test,y_pred)
stac_rec_a = recall_score(y_test,y_pred)
stac_f1_a = f1_score(y_test,y_pred)

# %%
calculateMetrics("Stacking", predict, y_test)#calculate accuracy and other metrics
# Out:
# Stacking Accuracy  : 96.04113110539846
# Stacking Precision   : 96.03717216582064
# Stacking Recall      : 96.04447617536623
# Stacking FMeasure    : 96.04018904716264

# %%
storeResults('Stacking Classifier',stac_acc_a,stac_prec_a,stac_rec_a,stac_f1_a)

# %%
#using shapely we can explain model which can show what features help in gaining more accuracy
columns = ['gender','age','hypertension','heart_disease','ever_married','work_type','Residence_type','avg_glucose_level','bmi']
explainer = shap.TreeExplainer(cb_cls)
shap_values = explainer.shap_values(X_train) #explainer will set on training data
shap.summary_plot(shap_values, X_train, feature_names=columns)#now explain features importance using plot

# %%
#plot comparison between all algortihms
df = pd.DataFrame([['Random Forest','Precision',precision[0]],['Random Forest','Recall',recall[0]],['Random Forest','F1 Score',fscore[0]],['Random Forest','Accuracy',accuracy[0]],
                   ['Logistic Regression','Precision',precision[1]],['Logistic Regression','Recall',recall[1]],['Logistic Regression','F1 Score',fscore[1]],['Logistic Regression','Accuracy',accuracy[1]],
                   ['SVM','Precision',precision[2]],['SVM','Recall',recall[2]],['SVM','F1 Score',fscore[2]],['SVM','Accuracy',accuracy[2]],
                   ['KNN','Precision',precision[3]],['KNN','Recall',recall[3]],['KNN','F1 Score',fscore[3]],['KNN','Accuracy',accuracy[3]],
                   ['Naive Bayes','Precision',precision[4]],['Naive Bayes','Recall',recall[4]],['Naive Bayes','F1 Score',fscore[4]],['Naive Bayes','Accuracy',accuracy[4]],
                   ['XGBoost','Precision',precision[5]],['XGBoost','Recall',recall[5]],['XGBoost','F1 Score',fscore[5]],['XGBoost','Accuracy',accuracy[5]],
                   ['Extension CatBoost','Precision',precision[6]],['Extension CatBoost','Recall',recall[6]],['Extension CatBoost','F1 Score',fscore[6]],['Extension CatBoost','Accuracy',accuracy[6]],
                   ['Extension Stacking','Precision',precision[7]],['Extension Stacking','Recall',recall[7]],['Extension Stacking','F1 Score',fscore[7]],['Extension Stacking','Accuracy',accuracy[7]],
                  ],columns=['Parameters','Algorithms','Value'])
df.pivot("Parameters", "Algorithms", "Value").plot(kind='bar')
plt.title("All Algorithms Performance Graph")
plt.show()

# %%
#creating dataframe
result = pd.DataFrame({ 'ML Model' : ML_Model,
                        'Accuracy' : acc,
                       'Precision': prec, 
                       'f1_score' : f1,
                        'Recall'   : rec,
                        
                      })

# %%
result
# Out:
#               ML Model  Accuracy  Precision  f1_score  Recall
# 0        Random Forest     0.952      0.952     0.952   0.952
# 1  Logistic Regression     0.777      0.777     0.777   0.778
# 2                  SVM     0.809      0.808     0.808   0.812
# 3                  KNN     0.927      0.926     0.927   0.932
# 4          Naive BAyes     0.752      0.751     0.751   0.752
# 5              XGBoost     0.895      0.895     0.895   0.897
# 6             CatBoost     0.960      0.960     0.960   0.960
# 7  Stacking Classifier     0.999      0.999     0.999   0.999

# %% [markdown]
# # Graph

# %%
classifier = ML_Model
y_pos = np.arange(len(classifier))

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, acc, align='center', alpha=0.5,color='blue')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Accuracy Score')
plt2.title('Classification Performance')
plt2.show()

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, prec, align='center', alpha=0.5,color='red')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Precision Score')
plt2.title('Classification Performance')
plt2.show()

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, rec, align='center', alpha=0.5,color='yellow')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Recall Score')
plt2.title('Classification Performance')
plt2.show()

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, f1, align='center', alpha=0.5,color='pink')
plt2.yticks(y_pos, classifier)
plt2.xlabel('F1 Score')
plt2.title('Classification Performance')
plt2.show()

# %%
import joblib
filename = 'model.sav'
joblib.dump(clf, filename)
# Out:
# ['model.sav']
